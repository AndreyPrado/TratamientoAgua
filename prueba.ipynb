# %%
import pandas as pd
import seaborn as sns

base = pd.read_excel("data/base_agua_limpia_julio.xlsx")

# %%
base = base.select_dtypes(include="number")

matriz = base.corr()

plt.figure(figsize=(12,10))
sns.heatmap(matriz, cmap = "coolwarm", fmt = ".2f", square = True)
plt.tight_layout()
plt.show()

# %%
matriz
# Out:
#                  latitud  longitud  profundidad  salinidad   oxigeno  \
# latitud         1.000000  0.702084    -0.261141  -0.109706 -0.092883
# longitud        0.702084  1.000000    -0.332691  -0.205445 -0.190294
# profundidad    -0.261141 -0.332691     1.000000   0.152513 -0.010326
# salinidad      -0.109706 -0.205445     0.152513   1.000000 -0.096128
# oxigeno        -0.092883 -0.190294    -0.010326  -0.096128  1.000000
# sat_oxigen     -0.212447 -0.316154    -0.583150   0.428700  0.196824
# precipitacionj -0.807067 -0.371723     0.187266   0.269427 -0.173986
# tempaguaj       0.451202 -0.099665    -0.113385   0.450374 -0.061628
# colifecalj     -0.295142 -0.046846    -0.114991  -0.531934  0.124765
# ecolij         -0.324506 -0.059129    -0.116297  -0.485325  0.202546
# enterococoj    -0.325391 -0.046610    -0.119399  -0.527517  0.061410
# tempairej      -0.047014 -0.623651     0.225952   0.285176  0.076072
# ph             -0.177182 -0.318421     0.113938   0.035515  0.163537
# ...
